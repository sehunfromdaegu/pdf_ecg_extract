# %% [markdown]
# # PDF ECG extract

# %%
from pdf_module import waves_and_features

# Extract PDFs in dir
directory = './ECG Sample 4 Hospitals/3. YSEV/'
waves, features = waves_and_features(directory)

# %%
# list of 13 waves (lead2 + lead1~12) of the first PDF
waves[0]
# Out:
# [array([ -78.,  -78.,  -78., ..., -278., -278., -278.]),
#  array([-20., -20., -20., ..., -44., -44., -44.]),
#  array([-78., -78., -78., ...,  -5.,  -5.,  -5.]),
#  array([-59., -59., -59., ...,  34.,  34.,  34.]),
#  array([  34.,   34.,   34., ..., -161., -161., -161.]),
#  array([-39., -39., -39., ...,  83.,  88.,  88.]),
#  array([ 5.,  5.,  5., ..., 73., 68., 68.]),
#  array([  0.,   0.,   0., ..., -20., -20., -20.]),
#  array([161., 156., 146., ..., -59., -59., -59.]),
#  array([127., 127., 122., ..., -59., -59., -54.]),
#  array([ 312.,  327.,  371., ..., -454., -454., -459.]),
#  array([ 410.,  429.,  488., ..., -527., -527., -527.]),
#  array([ 322.,  346.,  415., ..., -517., -517., -512.])]

# %%
# features of the first PDF
features[0]
# Out:
# {'patient_id': '11023702',
#  'file_name': 'EKG_11023702.pdf',
#  'study_date': '2024-01-12',
#  'study_time': '16:01:21',
#  'gender': 'MALE',
#  'age': '39',
#  'Heart rate': '66',
#  'PR Interval': '176',
#  'QRS Interval': '124',
#  'QT Interval': '384',
#  'QTc Interval': '402',
#  'P Axis': '49',
#  'QRS Axis': '-13',
#  'T Axis': '22',
#  'interpretation': [{'Diagnosis': 'Normal sinus rhythm'},
#   {'Diagnosis': 'Nonspecific intraventricular conduction delay'},
#   {'Diagnosis': 'Borderline ECG'},
#   {'Diagnosis': 'No previous ECGs available'}]}

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(waves[0][0])
